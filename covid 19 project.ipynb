# %%
import numpy as np

# %%
import pandas as pd

# %%
covdeath = pd.read_csv('covid_deaths.csv')

# %%
covdeath.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  24-02-2020  40099462.0          5.0
# 1      AFG      Asia  Afghanistan  25-02-2020  40099462.0          5.0
# 2      AFG      Asia  Afghanistan  26-02-2020  40099462.0          5.0
# 3      AFG      Asia  Afghanistan  27-02-2020  40099462.0          5.0
# 4      AFG      Asia  Afghanistan  28-02-2020  40099462.0          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    reproduction_rate  icu_patients  icu_patients_per_million  hosp_patients  \
# ...

# %%
covdeath['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
covdeath.drop('new_cases_smoothed',axis=1,inplace=True)

# %%
covdeath.drop(['new_deaths_smoothed','reproduction_rate','icu_patients','icu_patients_per_million','hosp_patients']
              ,axis =1,inplace=True)

# %%
 covdeathNG = covdeath[covdeath['location']=='Nigeria']

# %%
covdeathNG [covdeathNG['total_cases'] == covdeathNG['total_cases'].max()]
# Out:
#        iso_code continent location        date   population  total_cases  \
# 132635      NGA    Africa  Nigeria  14-07-2022  213401323.0     258934.0
# 132636      NGA    Africa  Nigeria  15-07-2022  213401323.0     258934.0
#
#         new_cases  total_deaths  new_deaths  total_cases_per_million  ...  \
# 132635       60.0        3144.0         0.0                 1213.366  ...
# 132636        0.0        3144.0         0.0                 1213.366  ...
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 132635                           0.868                    14.733
# 132636                           0.868                    14.733
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 132635                     0.0                              0.0
# 132636                     0.0                              0.0
#
#         hosp_patients_per_million  weekly_icu_admissions  \
# 132635                        NaN                    NaN
# ...

# %%
covdeath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201499 entries, 0 to 201498
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   iso_code                            201499 non-null  object
#  1   continent                           189827 non-null  object
#  2   location                            201499 non-null  object
#  3   date                                201499 non-null  object
#  4   population                          200292 non-null  float64
#  5   total_cases                         193433 non-null  float64
#  6   new_cases                           193185 non-null  float64
#  7   total_deaths                        174757 non-null  float64
#  8   new_deaths                          174733 non-null  float64
#  9   total_cases_per_million             192543 non-null  float64
#  10  new_cases_per_million               192295 non-null  float64
# ...

# %%
covdeath[covdeath['continent'].notnull()].sort_values(by = 'new_cases',ascending=False)
# Out:
#        iso_code      continent        location        date   population  \
# 190579      USA  North America   United States  10-01-2022  336997624.0
# 190587      USA  North America   United States  18-01-2022  336997624.0
# 190572      USA  North America   United States  03-01-2022  336997624.0
# 190593      USA  North America   United States  24-01-2022  336997624.0
# 190588      USA  North America   United States  19-01-2022  336997624.0
# ...         ...            ...             ...         ...          ...
# 193343      URY  South America         Uruguay  14-07-2022    3426260.0
# 193344      URY  South America         Uruguay  15-07-2022    3426260.0
# 198067      ESH         Africa  Western Sahara  20-04-2022     565581.0
# 199097      YEM           Asia           Yemen  11-08-2020   32981641.0
# 200694      ZWE         Africa        Zimbabwe  02-05-2020   15993524.0
#
#         total_cases  new_cases  total_deaths  new_deaths  \
# ...

# %%
 dategb = covdeath.groupby('date')
 dategb.sum()['new_deaths'].sort_values(ascending=False)
# Out:
# date
# 20-01-2021    77115.0
# 26-01-2021    75796.0
# 27-01-2021    73698.0
# 05-02-2021    73491.0
# 21-01-2021    73088.0
#                ...
# 09-01-2020        0.0
# 14-01-2020        0.0
# 10-01-2020        0.0
# 02-01-2020        0.0
# 01-01-2020        0.0
# Name: new_deaths, Length: 927, dtype: float64

# %%
covdeath['new_cases'].sum()
# Out:
# 2396551976.0
